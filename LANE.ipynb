# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from PIL import Image
import os

# %%
base_dir = '/content/gdrive/My Drive/amazing'
direction_path = [ os.path.join(base_dir,p)  for p in os.listdir(base_dir)]

# %%
direction_path
# Out:
# ['/content/gdrive/My Drive/amazing/0',
#  '/content/gdrive/My Drive/amazing/1',
#  '/content/gdrive/My Drive/amazing/2']

# %%
X = []
Y = []

for i,path in enumerate(direction_path):
  print(i)
  for img in os.listdir(path):
    
   
     
    img_path = os.path.join(path,img)
    IMG = cv2.imread(img_path)
    IMG = cv2.resize(IMG, (128,128))
    IMG = np.array(IMG).astype('float32') / 255.
    X.append(IMG)
    Y.append(i)
# Out:
# 0
# 1
# 2

# %%
X1 = np.array(X)
Y1 = np.array(Y)

from keras.utils import to_categorical

Y1 = to_categorical(Y1 , num_classes = 3)

print(X1.shape)
print(Y1.shape)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test , y_train, y_test = train_test_split(X1, Y1, test_size = 0.1, shuffle = True)


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3307, 128, 128, 3)
# (3307, 3)
# (368, 128, 128, 3)
# (368, 3)

# %%
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization, Flatten
from keras.models import Sequential

# %%
model = Sequential()
model.add(Conv2D(16 , kernel_size = (3,3) , strides = (2,2) , padding = 'same' , activation = 'relu', input_shape = (128,128,3)))
model.add(MaxPooling2D(pool_size = (2,2)))  # 64x64x16
model.add(BatchNormalization())

model.add(Conv2D(32 , kernel_size = (3,3) , strides = (2,2) , padding = 'same' , activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))  # 32X32x32
model.add(BatchNormalization())

model.add(Conv2D(32 , kernel_size = (3,3) , strides = (2,2) , padding = 'same' , activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))  # 16x16x32
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(1024 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(512 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(256 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(256 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(128 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(128 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(64 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(3 , activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy' , optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, epochs = 11, validation_split = 0.1, batch_size = 16)
# Out:
# Train on 2976 samples, validate on 331 samples
# Epoch 1/11
# 2976/2976 [==============================] - 5s 2ms/step - loss: 0.9342 - acc: 0.5255 - val_loss: 1.0129 - val_acc: 0.7311
# Epoch 2/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.3902 - acc: 0.8797 - val_loss: 0.3225 - val_acc: 0.9033
# Epoch 3/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.2355 - acc: 0.9241 - val_loss: 0.2294 - val_acc: 0.9305
# Epoch 4/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.1781 - acc: 0.9456 - val_loss: 0.4263 - val_acc: 0.8852
# Epoch 5/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.1404 - acc: 0.9560 - val_loss: 0.1968 - val_acc: 0.9486
# Epoch 6/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.1207 - acc: 0.9681 - val_loss: 1.9857 - val_acc: 0.6556
# Epoch 7/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.1075 - acc: 0.9684 - val_loss: 0.2368 - val_acc: 0.9486
# Epoch 8/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.1285 - acc: 0.9657 - val_loss: 1.0976 - val_acc: 0.8278
# Epoch 9/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.0924 - acc: 0.9731 - val_loss: 0.1742 - val_acc: 0.9698
# Epoch 10/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.0743 - acc: 0.9778 - val_loss: 0.0535 - val_acc: 0.9849
# Epoch 11/11
# 2976/2976 [==============================] - 3s 1ms/step - loss: 0.0919 - acc: 0.9721 - val_loss: 0.4413 - val_acc: 0.8550

# %%
model.evaluate(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-427f7c4e90e5> in <module>()
# ----> 1 model.evaluate(X_test,y_test)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1286             x, y,
#    1287             sample_weight=sample_weight,
# -> 1288             batch_size=batch_size)
#    1289         # Prepare inputs, delegate logic to `test_loop`.
#    1290         if self._uses_dynamic_learning_phase():
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     685         if y is not None:
#     686             if not self.optimizer:
# --> 687                 raise RuntimeError('You must compile a model before '
#     688                                    'training/testing. '
#     689                                    'Use `model.compile(optimizer, loss)`.')
#
# RuntimeError: You must compile a model before training/testing. Use `model.compile(optimizer, loss)`.

# %%
model.predict_classes(X_test)
# Out:
# array([2, 2, 2, 1, 2, 2, 1, 2, 0, 2, 0, 0, 1, 1, 0, 2, 1, 2, 1, 2, 2, 2,
#        2, 1, 2, 0, 0, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 1, 2, 0, 2, 0, 1, 1,
#        2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 0,
#        2, 2, 1, 1, 2, 0, 2, 1, 2, 0, 2, 0, 2, 2, 2, 0, 1, 2, 2, 2, 0, 2,
#        1, 0, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 0, 2, 1, 0, 1,
#        2, 1, 2, 2, 1, 2, 1, 0, 0, 0, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 0, 2,
#        2, 2, 2, 0, 2, 2, 2, 2, 1, 1, 2, 1, 2, 2, 1, 1, 2, 1, 2, 1, 2, 2,
#        0, 2, 2, 2, 2, 0, 2, 1, 0, 1, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0,
#        2, 1, 0, 2, 1, 2, 2, 1, 2, 2, 0, 2, 2, 1, 0, 0, 2, 2, 0, 2, 0, 1,
#        2, 2, 2, 2, 2, 1, 2, 0, 1, 1, 1, 1, 0, 1, 2, 2, 1, 2, 0, 2, 2, 2,
#        2, 2, 0, 1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 1,
#        2, 1, 0, 2, 2, 2, 2, 2, 2, 1, 2, 0, 0, 0, 2, 2, 1, 2, 1, 2, 2, 2,
#        2, 2, 2, 0, 2, 2, 2, 1, 2, 2, 1, 2, 2, 0, 2, 2, 1, 2, 1, 1, 2, 0,
#        2, 2, 2, 2, 2, 0, 0, 1, 2, 2, 1, 2, 2, 0, 2, 1, 2, 2, 2, 2, 2, 1,
#        2, 1, 2, 0, 0, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 0, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 1, 2, 1, 0, 2, 1, 1, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 1,
#        1, 2, 2, 1, 2, 1, 2, 2, 2, 1, 2, 0, 2, 2, 2, 1, 2, 0, 2, 2, 1, 1,
#        1, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 2, 1, 2, 2, 2, 2, 2, 0, 2, 1, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2,
#        2, 1, 2, 2, 0, 2, 2, 2, 1, 0, 0, 1, 1, 2, 1, 1, 1, 2, 2, 2, 2, 2,
#        1, 2, 2, 2, 2, 0])

# %%
model.save("model5.h5")

# %%
for y in y_test:
  print(np.argmax(y))
# Out:
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 0
# 2
# 1
# 2
# 1
# 2
# 0
# 1
# 1
# 2
# 1
# 2
# 1
# 0
# 0
# 2
# 2
# 1
# 1
# 0
# 2
# 0
# 1
# 0
# 1
# 2
# 1
# 1
# 2
# 0
# 1
# 1
# 2
# 1
# 2
# 0
# 1
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 1
# 0
# 0
# 0
# 2
# 2
# 0
# 1
# 1
# 0
# 2
# 2
# 0
# 1
# 2
# 2
# 2
# 0
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 0
# 1
# 0
# 1
# 2
# 2
# 2
# 2
# 0
# 2
# 0
# 0
# 0
# 2
# 1
# 0
# 1
# 1
# 1
# 2
# 0
# 2
# 2
# 1
# 0
# 2
# 2
# 2
# 1
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 1
# 0
# 2
# 0
# 0
# 0
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 0
# 2
# 0
# 0
# 1
# 0
# 2
# 2
# 0
# 2
# 2
# 0
# 0
# 0
# 2
# 2
# 0
# 1
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 0
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 0
# 2
# 2
# 0
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 0
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 0
# 0
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 1
# 0
# 2
# 2
# 0
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 1
# 2
# 1
# 0
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 0
# 2
# 2
# 2
# 0
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 0
# 1
# 0
# 2
# 2
# 2
# 0
# 0
# 1
# 1
# 2
# 2
# 2
# 1
# 2
# 1
# 0
# 0
# 2
# 2
# 2
# 2
# 0
# 1
# 2
# 0
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 1
# 0
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 2
# 2
# 2
# 0
# 2
# 2
# 0
# 2
# 2
# 0
# 2
# 2
# 0
# 2
# 0
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 1
# 2
# 2
# 0
# 2
# 2
# 1
# 0
# 2
# 2
# 0
# 0
# 0
# 2
# 2
# 1
# 0
# 1
# 0
# 1
# 0
# 2
# 0
# 2
# 2
# 0
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 0
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 0
# 2
# 1
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 1
# 2
# 0
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 0
# 0
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 0
# 2
# 2
# 1
# 1
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 1
# 1
# 2
# 2
# 0
# 2
# 1
# 1
# 1
# 2
# 0
# 0
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 0
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 0
# 2
# 1
# 1
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 2
